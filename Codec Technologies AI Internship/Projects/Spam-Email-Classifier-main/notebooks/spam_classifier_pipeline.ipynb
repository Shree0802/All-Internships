# %% [markdown]
# # Spam Email Classifier - Notebook Pipeline
# This notebook demonstrates the end-to-end Machine Learning and NLP pipeline for classifying emails into **Spam** or **Ham (Not Spam)**.

# %%
import sys
from pathlib import Path
root_dir = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(root_dir) not in sys.path:
    sys.path.insert(0, str(root_dir))

import pandas as pd
from src.utils import load_data
from src.preprocessing import preprocess_dataframe
from src.train import train_and_evaluate
from src.predict import SpamPredictor

# %% [markdown]
# ## 1. Load Dataset
# Fetch and inspect the dataset.

# %%
df = load_data(processed=True)
df.head()

# %% [markdown]
# ## 2. Train Models and Benchmark
# Train Naive Bayes, Logistic Regression, and Support Vector Machines (SVM).

# %%
best_name, res_df = train_and_evaluate()
print("Best Model Selected:", best_name)
res_df

# %% [markdown]
# ## 3. Test Inference Engine
# Run sample predictions with `SpamPredictor`.

# %%
predictor = SpamPredictor()
res = predictor.predict("FREE CASH PRIZE! Click http://claim.com to win $1000 now!")
print(res)
